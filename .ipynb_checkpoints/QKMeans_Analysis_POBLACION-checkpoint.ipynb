# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from qiskit import Aer

# %%
dataset = pd.read_excel('POBLACION_MEDELLIN_1993_A_2O20.xlsx', engine='openpyxl')
X_train, X_test = train_test_split(dataset, train_size=0.9)
X_train
# Out:
#      Hombres 1993  Mujeres 1993  Hombres 2005  Mujeres 2005  Hombres 2006  \
# 344          4269          4296          5714          5644          5945
# 18           6381          6252          5893          5675          5805
# 163          1929          1920          3201          3382          3271
# 70           5420          5210          6202          5923          5940
# 198          1936          2173          2872          3498          2991
# ..            ...           ...           ...           ...           ...
# 220             7             6            14            24            15
# 273           896           882          1313          1218          1613
# 303           698           952           908          1280           862
# 89           7295          7161          7148          7501          7429
# 332            97            91           312           295           334
#
#      Mujeres 2006  Hombres 2007  Mujeres 2007  Hombres 2008  Mujeres 2008  \
# ...

# %%
import sys
sys.path.append("..")

from quantum_k_means_1 import *

provider = IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-ornl', group='ornl', project='phy141')
backend = provider.get_backend('ibmq_qasm_simulator')
qkmeans_instances = [QuantumKMeans(backend=backend, n_clusters=i, init='random', verbose=True, map_type='probability', tol=0.01, max_iter=3).fit(X_train, batch=True) for i in range(2,8,2)]

# %%
example = [list([0.0, 0.0087890625, 0.025390625, 0.0, 0.0654296875, 0.0, 0.0517578125, 0.0, 0.0009765625, 0.0, 0.00390625, 0.005859375, 0.0029296875, 0.0, 0.0048828125, 0.0, 0.005859375, 0.0, 0.0078125, 0.009765625, 0.00390625, 0.0087890625, 0.001953125, 0.001953125, 0.0009765625, 0.0009765625, 0.0009765625, 0.0048828125, 0.01171875, 0.0029296875, 0.0, 0.001953125, 0.0009765625, 0.09765625, 0.0087890625, 0.0, 0.001953125, 0.001953125, 0.03515625, 0.0009765625, 0.01953125, 0.005859375, 0.0, 0.0009765625, 0.005859375, 0.0, 0.0078125, 0.0107421875, 0.0302734375, 0.0048828125, 0.0, 0.0107421875, 0.0009765625, 0.015625, 0.0419921875, 0.001953125, 0.0205078125, 0.0048828125, 0.0, 0.0087890625, 0.0, 0.0009765625, 0.005859375, 0.0, 0.001953125, 0.0, 0.001953125, 0.001953125, 0.0009765625, 0.015625, 0.0009765625, 0.0, 0.001953125, 0.0009765625, 0.0009765625, 0.0, 0.0009765625, 0.0, 0.001953125, 0.00390625, 0.0966796875, 0.0, 0.0009765625, 0.0009765625, 0.0009765625, 0.02734375, 0.0029296875, 0.001953125, 0.0, 0.005859375, 0.05078125, 0.0126953125, 0.00390625, 0.00390625, 0.00390625, 0.0078125, 0.0, 0.0029296875, 0.01171875, 0.0, 0.0009765625, 0.00390625, 0.0009765625, 0.0009765625, 0.0, 0.0087890625, 0.0048828125, 0.0, 0.001953125, 0.0, 0.00390625, 0.015625, 0.0, 0.0, 0.0107421875, 0.001953125, 0.001953125, 0.0107421875, 0.001953125, 0.0, 0.0, 0.0078125, 0.033203125, 0.0078125, 0.00390625, 0.0, 0.0498046875, 0.001953125, 0.0048828125, 0.001953125, 0.0029296875, 0.0029296875, 0.0029296875, 0.0009765625, 0.0009765625, 0.0029296875, 0.0009765625, 0.0205078125, 0.017578125, 0.0029296875, 0.0009765625, 0.041015625, 0.0009765625, 0.0, 0.005859375, 0.0126953125, 0.013671875, 0.0009765625, 0.0029296875, 0
 0.0107421875, 0.0048828125, 0.0, 0.0146484375, 0.001953125, 0.0, 0.0, 0.0, 0.00390625, 0.0087890625, 0.0009765625, 0.0, 0.0009765625, 0.0078125, 0.0146484375, 0.01953125, 0.0068359375, 0.0068359375, 0.0078125, 0.0, 0.0, 0.0107421875, 0.0068359375, 0.00390625, 0.0009765625, 0.001953125, 0.0009765625, 0.0068359375, 0.0, 0.0068359375, 0.015625, 0.0029296875, 0.001953125, 0.005859375, 0.0068359375, 0.0029296875, 0.0009765625, 0.0009765625, 0.009765625, 0.0, 0.001953125, 0.001953125, 0.005859375, 0.005859375, 0.013671875, 0.0, 0.0, 0.005859375, 0.0029296875, 0.0, 0.0029296875, 0.01171875, 0.0029296875, 0.0, 0.0009765625, 0.00390625, 0.00390625, 0.0009765625, 0.0, 0.0107421875, 0.001953125, 0.0087890625, 0.0, 0.0, 0.0, 0.013671875, 0.0, 0.0048828125, 0.005859375, 0.0048828125, 0.00390625, 0.005859375, 0.0, 0.0009765625, 0.001953125, 0.0205078125, 0.0, 0.0009765625, 0.0009765625, 0.0, 0.0009765625, 0.0068359375, 0.0, 0.0107421875, 0.0, 0.005859375, 0.009765625, 0.013671875, 0.00390625, 0.0068359375, 0.0, 0.001953125, 0.00390625, 0.001953125, 0.0068359375, 0.0126953125, 0.0, 0.00390625, 0.0068359375, 0.0, 0.0029296875, 0.0, 0.0078125, 0.0, 0.0, 0.0029296875, 0.00390625, 0.0009765625, 0.0068359375, 0.0, 0.0, 0.0, 0.0068359375, 0.0, 0.001953125, 0.0, 0.0185546875, 0.0029296875, 0.0, 0.0068359375, 0.0, 0.0, 0.0009765625, 0.029296875, 0.0029296875, 0.0009765625, 0.0068359375, 0.0087890625, 0.005859375, 0.001953125, 0.0107421875, 0.0107421875, 0.001953125, 0.0009765625, 0.0, 0.009765625, 0.0009765625, 0.001953125, 0.0, 0.0, 0.0048828125, 0.0078125, 0.0068359375, 0.04296875, 0.009765625, 0.0068359375, 0.0029296875, 0.01171875, 0.0009765625, 0.0, 0.0009765625, 0.0, 0.0, 0.0068359375, 0.0146484375, 0.0009765625, 0.0458984375, 0.0009765625, 0.0, 0.0, 0.0009765625, 0.0107421875]), \
           list([0.0009765625, 0.0068359375, 0.0048828125, 0.001953125, 0.01171875, 0.01171875, 0.0, 0.0009765625, 0.0, 0.0048828125, 0.0009765625, 0.0029296875, 0.0107421875, 0.0, 0.0, 0.0078125, 0.0029296875, 0.0185546875, 0.0029296875, 0.0048828125, 0.0029296875])]

# %%
new_example = []
counter = 0
distances_row = []
for i in range(8):
    distances_row += example[i]
    if counter == (8//4)-1:
        new_example.append(distances_row)
        distances_row = []
        counter=0
    else:
        counter+=1
np.array(new_example)
# Out:
# array([[0.        , 0.00878906, 0.02539062, ..., 0.00585938, 0.00097656,
#         0.01464844],
#        [0.        , 0.015625  , 0.05273438, ..., 0.015625  , 0.        ,
#         0.015625  ],
#        [0.        , 0.01171875, 0.03808594, ..., 0.00878906, 0.        ,
#         0.02734375],
#        [0.00683594, 0.00292969, 0.01660156, ..., 0.00292969, 0.00488281,
#         0.00292969]])

# %%
distances_row = []
distances_row += example[0]
distances_row += example[1]
len(distances_row)
# Out:
# 321

# %%
example = [np.array(example[i]) for i in range(len(example))]
np.array(example).reshape((4,321))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-79f02cd8ad10> in <module>
#       1 example = [np.array(example[i]) for i in range(len(example))]
# ----> 2 np.array(example).reshape((4,321))
#
# ValueError: cannot reshape array of size 8 into shape (4,321)

# %%
np.array(example).reshape((4,321))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ce248cb70331> in <module>
# ----> 1 np.array(example).reshape((4,321))
#
# ValueError: cannot reshape array of size 8 into shape (4,321)

# %%
for tuple in X_train.itertuples(index=False):
    print(tuple[33])
# Out:
# 4871
# 4697
# 6190
# 5603
# 5324
# 3831
# 2214
# 4053
# 5788
# 3723
# 7152
# 1984
# 5597
# 2162
# 1600
# 327
# 8291
# 4820
# 1139
# 5691
# 6252
# 3808
# 2138
# 1383
# 712
# 891
# 2930
# 1110
# 385
# 933
# 5750
# 4945
# 7518
# 5850
# 4286
# 5580
# 1577
# 115
# 4588
# 6964
# 4788
# 2130
# 5131
# 4656
# 1018
# 5201
# 5402
# 5076
# 5618
# 385
# 1341
# 358
# 1789
# 1715
# 910
# 915
# 6166
# 1141
# 4906
# 2052
# 2824
# 8187
# 4149
# 4001
# 5731
# 4451
# 4833
# 5845
# 84
# 2530
# 2187
# 7883
# 4945
# 5341
# 50
# 2839
# 4129
# 281
# 5805
# 6068
# 3600
# 4496
# 3991
# 161
# 2248
# 4180
# 5738
# 4523
# 5657
# 4829
# 3885
# 3901
# 6496
# 4413
# 1456
# 5772
# 5366
# 5183
# 5663
# 3312
# 1692
# 7454
# 2170
# 268
# 1595
# 4385
# 5684
# 5781
# 3506
# 1124
# 2032
# 4836
# 3146
# 315
# 4000
# 4455
# 2444
# 7052
# 4131
# 4689
# 8418
# 116
# 3592
# 2224
# 3728
# 3312
# 3141
# 1331
# 917
# 4667
# 3805
# 68
# 1041
# 4240
# 4219
# 3230
# 3020
# 432
# 5609
# 2250
# 3462
# 6751
# 1670
# 6547
# 5796
# 3523
# ...

# %%
backend.configuration().to_dict()
# Out:
# {'backend_name': 'qasm_simulator',
#  'backend_version': '0.7.0',
#  'n_qubits': 29,
#  'basis_gates': ['u1',
#   'u2',
#   'u3',
#   'u',
#   'p',
#   'r',
#   'rx',
#   'ry',
#   'rz',
#   'id',
#   'x',
#   'y',
#   'z',
#   'h',
#   's',
#   'sdg',
#   'sx',
#   't',
#   'tdg',
#   'swap',
#   'cx',
#   'cy',
#   'cz',
#   'csx',
#   'cp',
#   'cu1',
#   'cu2',
#   'cu3',
#   'rxx',
#   'ryy',
#   'rzz',
#   'rzx',
#   'ccx',
#   'cswap',
#   'mcx',
#   'mcy',
#   'mcz',
#   'mcsx',
#   'mcp',
#   'mcu1',
#   'mcu2',
#   'mcu3',
#   'mcrx',
#   'mcry',
#   'mcrz',
#   'mcr',
#   'mcswap',
#   'unitary',
#   'diagonal',
#   'multiplexer',
#   'initialize',
#   'kraus',
#   'roerror',
#   'delay'],
#  'gates': [],
#  'local': True,
#  'simulator': True,
#  'conditional': True,
#  'open_pulse': False,
#  'memory': True,
#  'max_shots': 1000000,
#  'coupling_map': None,
#  'dynamic_reprate_enabled': False,
#  'description': 'A C++ QasmQobj simulator with noise',
# ...

# %% [markdown]
# Elbow method

# %%
import numpy as np
from scipy.spatial.distance import cdist

X = dataset
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}

for i in range(1,11):

  distortions.append(sum(np.min(cdist(X, qkmeans_instances[i-1].cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
  inertias.append(qkmeans_instances[i-1].inertia_)
 
  mapping1[i-1] = sum(np.min(cdist(X, qkmeans_instances[i-1].cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
  mapping2[i-1] = qkmeans_instances[i-1].inertia_

# %%
for key, val in mapping1.items():
    print(f'{key} : {val}')
# Out:
# 0 : 175.70930519910976
# 1 : 101.84057105421105
# 2 : 73.62267483568934
# 3 : 64.84945890272883
# 4 : 61.37408854729769
# 5 : 57.666744965031754
# 6 : 54.7252539281459
# 7 : 53.29277189383631
# 8 : 50.61325533100393
# 9 : 49.16422911384758

# %%
from matplotlib import pyplot as plt

plt.plot(range(1,11), distortions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method using Distortion')
plt.show()

# %%
for key, val in mapping2.items():
	print(f'{key} : {val}')
# Out:
# 0 : 478204140.5764739
# 1 : 169462272.7432738
# 2 : 107714303.40699385
# 3 : 83639651.84005532
# 4 : 70437453.19821498
# 5 : 60114784.17915313
# 6 : 53238167.55590144
# 7 : 47572190.936666355
# 8 : 41824782.73415925
# 9 : 38124150.803040594

# %%
plt.plot(range(1,11), inertias, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %% [markdown]
# Davies Bouldin score

# %%
from sklearn.metrics import davies_bouldin_score

davies_scores = []
for key, qkmeans_instance in enumerate(qkmeans_instances):
  if key >= 2: 
    davies_scores.append(davies_bouldin_score(X, qkmeans_instance.labels_))
    print(key,':',davies_scores[-1])
# Out:
# 2 : 0.7367433835025672
# 3 : 0.8880374926629598
# 4 : 0.9443733099061935
# 5 : 0.9046798510009055
# 6 : 0.8725616231726921
# 7 : 0.8808191130748537
# 8 : 0.8333559488243351
# 9 : 0.841422106776099

# %%
plt.plot(range(2,10), 1-np.array(davies_scores), 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Davies Score')
plt.title('The Elbow Method using Davies Score')
plt.show()

# %% [markdown]
# Calinski Harabasz score

# %%
from sklearn.metrics import calinski_harabasz_score

calinski_scores = []
for key, qkmeans_instance in enumerate(qkmeans_instances):
    if key >= 2: 
        calinski_scores.append(calinski_harabasz_score(X, qkmeans_instance.labels_))
        print(key,':',calinski_scores[-1])
# Out:
# 2 : 7976.356502836861
# 3 : 7291.58915561555
# 4 : 6709.532203725818
# 5 : 6447.154102831663
# 6 : 6165.039135721303
# 7 : 5991.272162253879
# 8 : 6041.044238134938
# 9 : 5939.7505917605995

# %%
plt.plot(range(2,10), calinski_scores, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Calinski Harabasz Score')
plt.title('The Elbow Method using Calinski Harabasz Score')
plt.show()

# %% [markdown]
# Silhouette score

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for key, qkmeans_instance in enumerate(qkmeans_instances):
    if key >= 2: 
        silhouette_scores.append(silhouette_score(X, qkmeans_instance.labels_, metric='euclidean'))
        print(key,':',silhouette_scores[-1])
# Out:
# 2 : 0.816931674901893
# 3 : 0.7950304880265217
# 4 : 0.7874575821232618
# 5 : 0.7782358323667316
# 6 : 0.7753194214318195
# 7 : 0.7563731352475379
# 8 : 0.733111812408649
# 9 : 0.7606784532575754

# %%
plt.plot(range(2,10), silhouette_scores, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Silhouette Score')
plt.title('The Elbow Method using Silhouette Score')
plt.show()
